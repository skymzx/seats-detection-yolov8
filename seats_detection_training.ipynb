# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 129.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %% [markdown]
# Importing data from Roboflow:

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="DFRAPJ5ad6Ubpu6wZEj3")
project = rf.workspace("kareems-workspace-1tyaf").project("seats-detection-lfkct")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Seats-Detection-2 in yolov8:: 100%|██████████| 1163/1163 [00:00<00:00, 6694.16it/s]

# %% [markdown]
# Training the model:

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/Seats-Detection-2/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='seats_detection_v2'
)
# Out:
# Ultralytics 8.4.42 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# Downloading from Colab:

# %%
# !zip -r /content/training_results_v2.zip /content/runs/detect/seats_detection_v2
from google.colab import files
files.download('/content/training_results_v2.zip')
files.download('/content/runs/detect/seats_detection_v2/weights/best.pt')
# Out:
#   adding: content/runs/detect/seats_detection_v2/ (stored 0%)
#   adding: content/runs/detect/seats_detection_v2/val_batch1_pred.jpg (deflated 12%)
#   adding: content/runs/detect/seats_detection_v2/BoxPR_curve.png (deflated 12%)
#   adding: content/runs/detect/seats_detection_v2/train_batch1040.jpg (deflated 7%)
#   adding: content/runs/detect/seats_detection_v2/train_batch1.jpg (deflated 6%)
#   adding: content/runs/detect/seats_detection_v2/confusion_matrix_normalized.png (deflated 29%)
#   adding: content/runs/detect/seats_detection_v2/BoxF1_curve.png (deflated 13%)
#   adding: content/runs/detect/seats_detection_v2/BoxP_curve.png (deflated 11%)
#   adding: content/runs/detect/seats_detection_v2/results.png (deflated 7%)
#   adding: content/runs/detect/seats_detection_v2/val_batch2_pred.jpg (deflated 14%)
#   adding: content/runs/detect/seats_detection_v2/train_batch0.jpg (deflated 5%)
#   adding: content/runs/detect/seats_detection_v2/BoxR_curve.png (deflated 13%)
# ...
